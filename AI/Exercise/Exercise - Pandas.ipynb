# %%
import pandas as pd
import numpy as np

# Load the CSV file into a DataFrame
boston_df = pd.read_csv('load_boston.csv')

# Display the first 5 rows
print(boston_df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# shape() : shows the rows and columns in a DataFrame
boston_df.shape
# Out:
# (506, 14)

# %% [markdown]
# Loading a Data From Excel to Pandas DataFrame <br>
# pd.read_excel('file_path')

# %% [markdown]
# Exporting a DataFrame to CSV <br>
# Syntax : DataFrame.to_csv('file_name')

# %%
# Creating a DataFrame with random values

rand = pd.DataFrame(np.random.rand(1,199))
print(rand)
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.355233  0.218784  0.926756  0.564156  0.783157  0.698348  0.411144
#
#         7         8         9    ...       189       190       191       192  \
# 0  0.634795  0.440575  0.904575  ...  0.403614  0.069616  0.761029  0.655314
#
#         193       194       195       196       197       198
# 0  0.877221  0.323209  0.790729  0.246096  0.132457  0.685698
#
# [1 rows x 199 columns]
