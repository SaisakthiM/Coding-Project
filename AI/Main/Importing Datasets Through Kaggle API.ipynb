# %%
# API - Application Program Inetrface

# installing Kaggle API

# !pip install Kaggle

# %% [markdown]
# Upload Kaggle.json file

# %%
# Configuring kaggle.json File
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [00:30<00:00, 101MB/s]
# 100% 2.27G/2.27G [00:30<00:00, 79.4MB/s]

# %%
from zipfile import ZipFile

with ZipFile('/content/Earthquake.zip', 'r') as zipObj:
  zipObj.extractall('/content/drive/MyDrive/Reources')

# %%
# Importing train.csv
import pandas as pd
import numpy as np

train = pd.read_csv('/content/drive/MyDrive/Reources/train.csv',
                    dtype={'acoustic_data': np.int16, 'time_to_failure':np.float64})

# %%
train.head(200)
# Out:
#      acoustic_data  time_to_failure
# 0               12           1.4691
# 1                6           1.4691
# 2                8           1.4691
# 3                5           1.4691
# 4                8           1.4691
# ..             ...              ...
# 195              6           1.4691
# 196              4           1.4691
# 197              7           1.4691
# 198              6           1.4691
# 199              5           1.4691
#
# [200 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.plot(train[:1000])
plt.xlabel('Accoustic_data')
plt.ylabel('Time_to_failure')
plt.show()

# %%
sns.scatterplot(train[:100])
# Out:
# <Axes: >

# %% [markdown]
# Coffee Prediction

# %%
# importing coffee dataset

# !kaggle competitions download -c skku-2024-1-machine-learning-first-project
# Out:
# ...
#   0% 0.00/28.6k [00:00<?, ?B/s]
# 100% 28.6k/28.6k [00:00<00:00, 56.3MB/s]

# %%
from zipfile import ZipFile

with ZipFile('//content/skku-2024-1-machine-learning-first-project.zip', 'r') as zipObj:
  zipObj.extractall('/content/drive/MyDrive/Reources')

# %%
import pandas as pd

coffee = pd.read_csv('/content/drive/MyDrive/Reources/train(Coffee).csv')
coffee.head(5)
# Out:
#    Unnamed: 0  Species              Farm.Name  Lot.Number  \
# 0           0  Arabica     conquista / morito         NaN
# 1           1  Arabica                    NaN         NaN
# 2           2  Arabica           la esmeralda  11/23/0634
# 3           3  Arabica  fazenda santo antonio         NaN
# 4           4  Arabica                    NaN         NaN
#
#                Altitude  Number.of.Bags Bag.Weight  Harvest.Year  \
# 0                   NaN             250       1 kg          2012
# 1  de 1.600 a 1.950 msn             275      70 kg  Mayo a Julio
# 2                  4000              25      69 kg          2017
# 3              900-1100             305       2 kg          2014
# 4                   NaN               1      5 lbs          2013
#
#            Grading.Date  Variety  ... Sweetness  Cupper.Points  \
# 0    January 13th, 2012  Bourbon  ...      10.0           7.00
# 1       July 29th, 2011  Caturra  ...      10.0           8.17
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            585 non-null    int64
#  1   Species               585 non-null    object
#  2   Farm.Name             419 non-null    object
#  3   Lot.Number            105 non-null    object
#  4   Altitude              518 non-null    object
#  5   Number.of.Bags        585 non-null    int64
#  6   Bag.Weight            585 non-null    object
#  7   Harvest.Year          575 non-null    object
#  8   Grading.Date          585 non-null    object
#  9   Variety               524 non-null    object
#  10  Processing.Method     533 non-null    object
#  11  Aroma                 585 non-null    float64
#  12  Flavor                585 non-null    float64
#  13  Aftertaste            585 non-null    float64
#  14  Acidity               585 non-null    float64
# ...

# %%
plt.plot(coffee['Sweetness','Expiration'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Sweetness', 'Expiration')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-606ca9ebf006> in <cell line: 1>()
# ----> 1 plt.plot(coffee['Sweetness','Expiration'])
#
# ...
