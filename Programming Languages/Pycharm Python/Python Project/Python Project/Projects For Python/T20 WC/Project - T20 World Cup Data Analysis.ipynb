# %% [markdown]
#                                 Python Project
#                                 T20 WC Analysis of Players
#
# To Do Analysis , We Need three Components,
# 1) Data Collection - We are going to use the data of bright data
# 2) Data Transformation - We are going to create the AI which predicts which player performs well with their past performance and other factors
# 3) DashBoarding - Showing the results of data in the simplest form using graphs . For that we can use Power BI or Matplotlib and Seaborn modules

# %%
import pandas as pd

data = pd.read_html('https://www.espncricinfo.com/series/icc-men-s-t20-world-cup-2024-1411166/stats')
