# %%
import setup
setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

User.objects.all()
# Out:
# <QuerySet [<User: saisakthi>]>

# %%
user_obj = User(
    username="Sai"
)

# %%
user_obj.save()

# %%
from django_ai.documents.models import Document #type: ignore
